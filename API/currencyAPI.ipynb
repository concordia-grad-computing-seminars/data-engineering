# %% [markdown]
# # Currency API

# %% [markdown]
# ## Description

# %% [markdown]
# This notebook illustrates how to access a simple online API for converting currencies.
#
# The link of the API is:
# https://open.er-api.com/v6/latest/CAD
#
# This API returns [`JSON`](https://www.json.org) data

# %% [markdown]
# ## Practical examples

# %%
import requests

# %%
# retrive some data using a request
url = "https://open.er-api.com/v6/latest/CAD"
req = requests.get(url)
data = req.json()

# %% [markdown]
# Let us check how looks the data

# %%
data
# Out:
# {'result': 'success',
#  'provider': 'https://www.exchangerate-api.com',
#  'documentation': 'https://www.exchangerate-api.com/docs/free',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1671408151,
#  'time_last_update_utc': 'Mon, 19 Dec 2022 00:02:31 +0000',
#  'time_next_update_unix': 1671496541,
#  'time_next_update_utc': 'Tue, 20 Dec 2022 00:35:41 +0000',
#  'time_eol_unix': 0,
#  'base_code': 'CAD',
#  'rates': {'CAD': 1,
#   'AED': 2.684858,
#   'AFN': 63.801814,
#   'ALL': 78.838958,
#   'AMD': 287.988394,
#   'ANG': 1.308617,
#   'AOA': 370.92578,
#   'ARS': 126.121538,
#   'AUD': 1.092432,
#   'AWG': 1.308617,
#   'AZN': 1.24222,
#   'BAM': 1.349624,
#   'BBD': 1.462142,
#   'BDT': 75.662155,
#   'BGN': 1.349606,
#   'BHD': 0.274883,
#   'BIF': 1511.912162,
#   'BMD': 0.731071,
#   'BND': 0.993757,
#   'BOB': 5.051299,
#   'BRL': 3.8798,
#   'BSD': 0.731071,
#   'BTN': 60.407471,
#   'BWP': 9.535211,
#   'BYN': 1.834469,
#   'BZD': 1.462142,
#   'CDF': 1501.765101,
#   'CHF': 0.682439,
#   'CLP': 644.683289,
#   'CNY': 5.103553,
#   'COP': 3499.99971,
#   'CRC': 430.002119,
#   'CUP': 17.545703,
#   'CVE': 76.088579,
#   'CZK': 16.713893,
#   'DJF': 129.926664,
#   'DKK': 5.14805,
#   'DOP': 40.400158,
#   'DZD': 100.539824,
#   'EGP': 18.041719,
#   'ERN': 10.966065,
#   'ETB': 39.070018,
#   'EUR': 0.689988,
#   'FJD': 1.613497,
#   'FKP': 0.601188,
#   'FOK': 5.14805,
#   'GBP': 0.601111,
#   'GEL': 1.93648,
#   'GGP': 0.601188,
#   'GHS': 6.635446,
#   'GIP': 0.601188,
#   'GMD': 46.17827,
#   'GNF': 6215.638889,
#   'GTQ': 5.751105,
#   'GYD': 152.635061,
#   'HKD': 5.688256,
#   'HNL': 18.04489,
#   'HRK': 5.199196,
#   'HTG': 106.910177,
#   'HUF': 280.082567,
#   'IDR': 11338.083917,
#   'ILS': 2.526543,
#   'IMP': 0.601188,
#   'INR': 60.407765,
#   'IQD': 1065.538095,
#   'IRR': 31770.783932,
#   'ISK': 104.018626,
#   'JEP': 0.601188,
#   'JMD': 112.064725,
#   'JOD': 0.518329,
#   'JPY': 99.786992,
#   'KES': 89.93651,
#   'KGS': 62.026376,
#   'KHR': 2983.506667,
#   'KID': 1.09211,
#   'KMF': 339.483309,
#   'KRW': 957.15203,
#   'KWD': 0.224075,
#   'KYD': 0.609226,
#   'KZT': 340.960093,
#   'LAK': 12515.305381,
#   'LBP': 1102.089489,
#   'LKR': 266.944544,
#   'LRD': 112.667404,
#   'LSL': 12.890426,
#   'LYD': 3.517788,
#   'MAD': 7.677309,
#   'MDL': 14.127873,
#   'MGA': 3242.179288,
#   'MKD': 42.5042,
#   'MMK': 1717.042427,
#   'MNT': 2514.191011,
#   'MOP': 5.858902,
#   'MRU': 27.435385,
#   'MUR': 32.271418,
#   'MVR': 11.281004,
#   'MWK': 747.728761,
#   'MXN': 14.46678,
#   'MYR': 3.234912,
#   'MZN': 46.788469,
#   'NAD': 12.890426,
#   'NGN': 326.026528,
#   'NIO': 26.605559,
#   'NOK': 7.234499,
#   'NPR': 96.651953,
#   'NZD': 1.148355,
#   'OMR': 0.281095,
#   'PAB': 0.731071,
#   'PEN': 2.804247,
#   'PGK': 2.591445,
#   'PHP': 40.584184,
#   'PKR': 164.359511,
#   'PLN': 3.234237,
#   'PYG': 5220.946381,
#   'QAR': 2.661098,
#   'RON': 3.390641,
#   'RSD': 80.893546,
#   'RUB': 47.35409,
#   'RWF': 782.259221,
#   'SAR': 2.741516,
#   'SBD': 5.953587,
#   'SCR': 9.726056,
#   'SDG': 326.185131,
#   'SEK': 7.602125,
#   'SGD': 0.9936,
#   'SHP': 0.601188,
#   'SLE': 13.721633,
#   'SLL': 13723.514478,
#   'SOS': 415.144712,
#   'SRD': 23.073108,
#   'SSP': 490.549775,
#   'STN': 16.906273,
#   'SYP': 1836.319783,
#   'SZL': 12.890426,
#   'THB': 25.515714,
#   'TJS': 7.461447,
#   'TMT': 2.558555,
#   'TND': 2.285221,
#   'TOP': 1.722115,
#   'TRY': 13.630424,
#   'TTD': 4.992797,
#   'TVD': 1.09211,
#   'TWD': 22.498949,
#   'TZS': 1697.210122,
#   'UAH': 26.986282,
#   'UGX': 2668.616216,
#   'USD': 0.731018,
#   'UYU': 28.298272,
#   'UZS': 8277.693719,
#   'VES': 11.526662,
#   'VND': 17304.98704,
#   'VUV': 87.75833,
#   'WST': 1.972561,
#   'XAF': 452.644412,
#   'XCD': 1.973892,
#   'XDR': 0.550369,
#   'XOF': 452.644412,
#   'XPF': 82.34528,
#   'YER': 182.911183,
#   'ZAR': 12.889265,
#   'ZMW': 12.910066,
#   'ZWL': 491.652967}}

# %% [markdown]
# This will return the rates

# %%
data['rates']
# Out:
# {'CAD': 1,
#  'AED': 2.684858,
#  'AFN': 63.801814,
#  'ALL': 78.838958,
#  'AMD': 287.988394,
#  'ANG': 1.308617,
#  'AOA': 370.92578,
#  'ARS': 126.121538,
#  'AUD': 1.092432,
#  'AWG': 1.308617,
#  'AZN': 1.24222,
#  'BAM': 1.349624,
#  'BBD': 1.462142,
#  'BDT': 75.662155,
#  'BGN': 1.349606,
#  'BHD': 0.274883,
#  'BIF': 1511.912162,
#  'BMD': 0.731071,
#  'BND': 0.993757,
#  'BOB': 5.051299,
#  'BRL': 3.8798,
#  'BSD': 0.731071,
#  'BTN': 60.407471,
#  'BWP': 9.535211,
#  'BYN': 1.834469,
#  'BZD': 1.462142,
#  'CDF': 1501.765101,
#  'CHF': 0.682439,
#  'CLP': 644.683289,
#  'CNY': 5.103553,
#  'COP': 3499.99971,
#  'CRC': 430.002119,
#  'CUP': 17.545703,
#  'CVE': 76.088579,
#  'CZK': 16.713893,
#  'DJF': 129.926664,
#  'DKK': 5.14805,
#  'DOP': 40.400158,
#  'DZD': 100.539824,
#  'EGP': 18.041719,
#  'ERN': 10.966065,
#  'ETB': 39.070018,
#  'EUR': 0.689988,
#  'FJD': 1.613497,
#  'FKP': 0.601188,
#  'FOK': 5.14805,
#  'GBP': 0.601111,
#  'GEL': 1.93648,
#  'GGP': 0.601188,
#  'GHS': 6.635446,
#  'GIP': 0.601188,
#  'GMD': 46.17827,
#  'GNF': 6215.638889,
#  'GTQ': 5.751105,
#  'GYD': 152.635061,
#  'HKD': 5.688256,
#  'HNL': 18.04489,
#  'HRK': 5.199196,
#  'HTG': 106.910177,
#  'HUF': 280.082567,
#  'IDR': 11338.083917,
#  'ILS': 2.526543,
#  'IMP': 0.601188,
#  'INR': 60.407765,
#  'IQD': 1065.538095,
#  'IRR': 31770.783932,
#  'ISK': 104.018626,
#  'JEP': 0.601188,
#  'JMD': 112.064725,
#  'JOD': 0.518329,
#  'JPY': 99.786992,
#  'KES': 89.93651,
#  'KGS': 62.026376,
#  'KHR': 2983.506667,
#  'KID': 1.09211,
#  'KMF': 339.483309,
#  'KRW': 957.15203,
#  'KWD': 0.224075,
#  'KYD': 0.609226,
#  'KZT': 340.960093,
#  'LAK': 12515.305381,
#  'LBP': 1102.089489,
#  'LKR': 266.944544,
#  'LRD': 112.667404,
#  'LSL': 12.890426,
#  'LYD': 3.517788,
#  'MAD': 7.677309,
#  'MDL': 14.127873,
#  'MGA': 3242.179288,
#  'MKD': 42.5042,
#  'MMK': 1717.042427,
#  'MNT': 2514.191011,
#  'MOP': 5.858902,
#  'MRU': 27.435385,
#  'MUR': 32.271418,
#  'MVR': 11.281004,
#  'MWK': 747.728761,
#  'MXN': 14.46678,
#  'MYR': 3.234912,
#  'MZN': 46.788469,
#  'NAD': 12.890426,
#  'NGN': 326.026528,
#  'NIO': 26.605559,
#  'NOK': 7.234499,
#  'NPR': 96.651953,
#  'NZD': 1.148355,
#  'OMR': 0.281095,
#  'PAB': 0.731071,
#  'PEN': 2.804247,
#  'PGK': 2.591445,
#  'PHP': 40.584184,
#  'PKR': 164.359511,
#  'PLN': 3.234237,
#  'PYG': 5220.946381,
#  'QAR': 2.661098,
#  'RON': 3.390641,
#  'RSD': 80.893546,
#  'RUB': 47.35409,
#  'RWF': 782.259221,
#  'SAR': 2.741516,
#  'SBD': 5.953587,
#  'SCR': 9.726056,
#  'SDG': 326.185131,
#  'SEK': 7.602125,
#  'SGD': 0.9936,
#  'SHP': 0.601188,
#  'SLE': 13.721633,
#  'SLL': 13723.514478,
#  'SOS': 415.144712,
#  'SRD': 23.073108,
#  'SSP': 490.549775,
#  'STN': 16.906273,
#  'SYP': 1836.319783,
#  'SZL': 12.890426,
#  'THB': 25.515714,
#  'TJS': 7.461447,
#  'TMT': 2.558555,
#  'TND': 2.285221,
#  'TOP': 1.722115,
#  'TRY': 13.630424,
#  'TTD': 4.992797,
#  'TVD': 1.09211,
#  'TWD': 22.498949,
#  'TZS': 1697.210122,
#  'UAH': 26.986282,
#  'UGX': 2668.616216,
#  'USD': 0.731018,
#  'UYU': 28.298272,
#  'UZS': 8277.693719,
#  'VES': 11.526662,
#  'VND': 17304.98704,
#  'VUV': 87.75833,
#  'WST': 1.972561,
#  'XAF': 452.644412,
#  'XCD': 1.973892,
#  'XDR': 0.550369,
#  'XOF': 452.644412,
#  'XPF': 82.34528,
#  'YER': 182.911183,
#  'ZAR': 12.889265,
#  'ZMW': 12.910066,
#  'ZWL': 491.652967}

# %% [markdown]
# And this returns the rate of a specific currency

# %%
data['rates']['USD']
# Out:
# 0.731018
