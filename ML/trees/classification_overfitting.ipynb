# %% [markdown]
# # Classification trees - Overfitting

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/concordia-grad-computing-seminars/data-engineering/blob/main/ML/trees/classification_overfitting.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd

from sklearn.datasets import make_moons
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_validate
from sklearn.model_selection import RepeatedKFold

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Synthetic data set

# %% [markdown]
# To illustrate the concepts we will use a synthetic data set which we generate using the [`make_moons`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html) function

# %%
X, y = make_moons(200, noise=0.3, random_state=1)

colors = np.array(['tab:blue', 'tab:orange'])
plt.scatter(X[:, 0], X[:, 1], s=10, color=colors[y])
plt.xlabel('$x_1$', fontsize=14)
plt.ylabel('$x_2$', fontsize=14)
plt.show()

# %% [markdown]
# ## Classification tree training

# %% [markdown]
# Without any extra restrictions, decision trees tends to not fit adequately.

# %%
clf = DecisionTreeClassifier()
clf.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
def plot_dec_bound(clf, X, y, ax):
    '''
    Plot decision boundaries
    '''
    plot_step = 0.02

    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                         np.arange(y_min, y_max, plot_step))

    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    cs = ax.contourf(xx, yy, Z-100, cmap=plt.cm.Greens)

    colors = np.array(['tab:blue', 'tab:orange'])
    ax.scatter(X[:, 0], X[:, 1], s=12, color=colors[y])
    
    ax.set_xlabel('$x_1$', fontsize=14)
    ax.set_ylabel('$x_2$', fontsize=14)

# %%
fig, ax = plt.subplots(1, 1)
plot_dec_bound(clf, X, y, ax)
plt.show()

# %% [markdown]
# Depending on the value of the hyper-parameter `min_samples_leaf` (minimum number of samples required to be at a leaf node), the classification can be over-fitted, optimal (more or less) or under-fitted.

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 4))
i = 0

for n in [1, 5, 15]:
    clf = DecisionTreeClassifier(min_samples_leaf=n)
    clf.fit(X, y)
    plot_dec_bound(clf, X, y, ax[i])
    ax[i].set_title('min_samples_leaf = ' + str(n))
    i = i+1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Cross validation can be used for tuning the hyper-parameter `min_samples_leaf` (minimum number of samples required to be at a leaf node).

# %%
MSE_train = []
MSE_valid = []

n_max = 16
n_range = range(1, n_max)
for n in n_range:
    clf = DecisionTreeClassifier(min_samples_leaf=n)
    clf.fit(X, y)
    scores = cross_validate(clf, X, y,
                            cv=RepeatedKFold(n_splits=5, n_repeats=100),
                            scoring='neg_mean_squared_error', return_train_score=True)
    MSE_train = np.append(MSE_train, -scores['train_score'].mean())
    MSE_valid = np.append(MSE_valid, -scores['test_score'].mean())

plt.plot(n_range, MSE_train, "o-", markersize=8, markerfacecolor='white', label='Training set')
plt.plot(n_range, MSE_valid, "s-", markersize=8, markerfacecolor='white', label='Validation set')
plt.xlabel('Number of nearest neighbors', fontsize=14)
plt.ylabel('MSE', fontsize=14)
plt.legend(loc='best')
plt.show()

# %%
n_opt = n_range[np.argmin(MSE_valid)]

clf = DecisionTreeClassifier(min_samples_leaf=n_opt)
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(min_samples_leaf=3)

# %%
fig, ax = plt.subplots(1, 1)
plot_dec_bound(clf, X, y, ax)
plt.show()

# %% [markdown]
# ## Suggested activities

# %% [markdown]
# * Read the documentation of the [`DecisionTreeClassifier`](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html) class. List the hyper-parameters which can be tuned and give a short definition of them.
# * Repeat the examples by tuning other hyper-parameters. Regularization is obtained by increasing the values of hyper-parameters of type `min_` or decreasing hyper-parameters of type `max_`.
